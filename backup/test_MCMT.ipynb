# %%
from __Detection.detection_api import DetectionAPI
from __Tracking.tracking_api import TrackerAPI
from tools.homo_graphy import PlanProjector

# %%
class Args:
    track_thresh = 0.1
    match_thresh = 0.9
    track_buffer = 180
    mot20 = False
    cpu_workers = 10   # 듀얼 CPU 적극 활용
    chunk_sec   = 10.0 # 15~30초 권장
    batch_size  = 20
args = Args()
DEFAULT_CLASSES= ["People"]

# %%
detector = DetectionAPI(models=["ultra_people", "worker"], class_names=DEFAULT_CLASSES)
tracker = TrackerAPI(args=args, detector=detector)
# Out:
# [DEBUG] VehicleDetector loaded with Ultralytics YOLO on cuda:0
# Loads checkpoint by local backend from path: /workspace/PretrainedModel_by_JeonYT/worker/epoch_100.pth
# [DEBUG] WorkerDetector loaded on device=cuda:0
# Parameter device: cuda:0

# %%
# 1) 도면 + (선택) H 로드
plan_path = "/workspace/assets/250904_homograph_coordinate-plane2.jpg"
plan_pts  = [
                (1170,  214),    #point1
                (1170,  559),   #point2
                (1170,  904),   #point3
                (2212,  214),    #point4
                (2212,  559),   #point5
                (2212,  904),   #point6
                (3255,  214),     #point7
                (3255,  559),    #point8
                (3255,  904),    #point9
                ]

# %% [markdown]
# ### Cam#1

# %%
cam1_tracklets = tracker.track_video(
    video_path="/workspace/datasets/homography_experiment2/1100-1110/2025-09-04 10_59_59 이동형 #1_part_000.mp4",
    save_path="/workspace/results/tracking_result1.mp4",
    trail_len=100
)
# Out:
# /opt/conda/envs/mmyolo/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [INFO] Tracking video saved: /workspace/results/tracking_result1.mp4, frames written: 18012

# %%
print(cam1_tracklets)
# Out:
# [[{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     859.46,      210.26,         136,      420.74], dtype=float32), 'score': 0.619815}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     860.35,      212.94,      134.21,      415.06], dtype=float32), 'score': 0.67925626}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     862.03,      218.16,      131.97,      408.09], dtype=float32), 'score': 0.6746358}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     862.98,      221.87,      130.45,      403.42], dtype=float32), 'score': 0.53441346}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([      864.5,      223.91,      129.45,       399.6], dtype=float32), 'score': 0.4284041}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     864.62,      225.41,      128.22,       395.2], dtype=float32), 'score': 0.6454993}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     863.87,       226.1,      127.85,      392.88], dtype=float32), 'score': 0.70234925}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     865.14,      226.43,      126.97,      389.58], dtype=float32), 'score': 0.65071}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     866.61,      226.27,      125.65,      384.68], dtype=float32), 'score': 0.75087774}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     868.03,      225.97,      124.47,      379.72], dtype=float32), 'score': 0.6679704}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     869.51,       225.8,      122.45,      371.45], dtype=float32), 'score': 0.71092594}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     870.22,      226.69,      120.44,      363.45], dtype=float32), 'score': 0.6876236}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     866.25,      204.06,      128.53,      387.23], dtype=float32), 'score': 0.7358097}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([      870.7,       218.7,      123.99,      370.95], dtype=float32), 'score': 0.7442488}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     868.89,      206.14,      129.05,      386.36], dtype=float32), 'score': 0.70780987}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     870.03,       203.2,      129.71,      388.53], dtype=float32), 'score': 0.7298039}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([      870.8,      202.15,      129.84,      389.12], dtype=float32), 'score': 0.71048933}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     877.45,      220.81,      123.61,      369.73], dtype=float32), 'score': 0.60260606}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     881.88,      229.58,      121.12,      360.31], dtype=float32), 'score': 0.63215595}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([      886.2,       236.4,      118.44,      351.79], dtype=float32), 'score': 0.6558197}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     892.26,      242.02,      116.43,      344.23], dtype=float32), 'score': 0.6223089}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     894.63,      243.66,      115.44,      339.34], dtype=float32), 'score': 0.526432}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     897.06,      244.58,      116.49,      337.64], dtype=float32), 'score': 0.6177838}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     898.37,      245.25,      115.78,      332.14], dtype=float32), 'score': 0.5271109}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     897.77,      245.39,       112.6,      322.65], dtype=float32), 'score': 0.4589544}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([      900.3,      243.11,      109.46,      315.56], dtype=float32), 'score': 0.6280339}], [{'id': 1, 'class_id': 0, 'label': 'People', 'bbox': array([     904 ...

# %%
# 2) 대응점으로 H 추정 (리스트 안에 '튜플' 형태) --> 예시 나중에 바꿔야함
projector1 = PlanProjector(plan_path, trail_len=60, trail_ttl=30, line_thickness=4, point_radius=6)
cam1_pts = [(1033,475),
            (948,474),
            (863,473),
            (1019,527),
            (890,524),
            (769,519),
            (973,667),
            (741,652),
            (548,620)]
H1, mask1 = projector1.fit_homography(cam1_pts, plan_pts, ransac_thresh=3.0)
# 4-2) 전체 프레임 미니맵 비디오 저장
projector1.save_video(cam1_tracklets, "/workspace/results/plan_projection1.mp4", fps=30, mode="bottom-center")

# %% [markdown]
# ### Cam#2

# %%
cam2_tracklets = tracker.track_video(
    #video_path="/workspace/datasets/2025-09-04 10_59_58 이동형 #2_part_000_part_000.mp4",
    video_path="/workspace/datasets/homography_experiment2/1100-1110/2025-09-04 10_59_58 이동형 #2_part_000.mp4",
    save_path="/workspace/results/tracking_result2.mp4",
    trail_len=100
)
# Out:
# [INFO] Tracking video saved: /workspace/results/tracking_result2.mp4, frames written: 18013

# %%
# 2) 대응점으로 H 추정 (리스트 안에 '튜플' 형태) --> 예시 나중에 바꿔야함
projector2 = PlanProjector(plan_path, trail_len=60, trail_ttl=30, line_thickness=4, point_radius=6)
cam2_pts = [(518,466),
            (430,471),
            (341,474),
            (613,510),
            (485,519),
            (354,527),
            (829,608),
            (634,645),
            (397,668)]
H2, mask2 = projector2.fit_homography(cam2_pts, plan_pts, ransac_thresh=3.0)
# 4-2) 전체 프레임 미니맵 비디오 저장
projector2.save_video(cam2_tracklets, "/workspace/results/plan_projection2.mp4", fps=30, mode="bottom-center")

# %% [markdown]
#  ### Cam#3

# %%
cam3_tracklets = tracker.track_video(
    video_path="/workspace/datasets/homography_experiment2/1100-1110/2025-09-04 10_59_58 이동형 #3_part_000.mp4",
    save_path="/workspace/results/tracking_result3.mp4",
    trail_len=100
)
# Out:
# [INFO] Tracking video saved: /workspace/results/tracking_result3.mp4, frames written: 18011

# %%
# 2) 대응점으로 H 추정 (리스트 안에 '튜플' 형태) --> 예시 나중에 바꿔야함
projector3 = PlanProjector(plan_path, trail_len=60, trail_ttl=30, line_thickness=4, point_radius=6)
cam3_pts = [(357,602),
            (566,648),
            (832,683),
            (620,498),
            (754,509),
            (893,513),
            (726,453),
            (819,456),
            (911,459)]

H3, mask3 = projector3.fit_homography(cam3_pts, plan_pts, ransac_thresh=3.0)
# 4-2) 전체 프레임 미니맵 비디오 저장
projector3.save_video(cam3_tracklets, "/workspace/results/plan_projection3.mp4", fps=30, mode="bottom-center")
