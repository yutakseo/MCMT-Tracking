# %%
import cv2
from __Detection.ensemble_detection._base_ import EnsembleDetector
from __Detection.tools.show import show_detections

# %%
det = EnsembleDetector(thres=0.3)
# Out:
# Loads checkpoint by local backend from path: /workspace/custom_pre-trained-model_by_JeonYT/vehicle/epoch_54.pth
# Loads checkpoint by local backend from path: /workspace/custom_pre-trained-model_by_JeonYT/worker/epoch_100.pth

# %%
img_path = "/workspace/input/0000000.png"

# %%
img = cv2.imread(img_path)  # Replace with your image path  
result = det.detect(img)
# Out:
# /opt/conda/envs/mmyolo/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
show_detections(
    image_or_path=img_path, 
    detections_result=result, 
    score_thr=0.0, 
    save_path=None
    )
# Out:
# array([[[ 87,  81,  55],
#         [ 80,  74,  48],
#         [ 67,  61,  35],
#         ...,
#         [ 88, 108, 110],
#         [ 85, 112, 113],
#         [ 87, 114, 115]],
#
#        [[ 87,  81,  55],
#         [ 80,  74,  48],
#         [ 67,  61,  35],
#         ...,
#         [ 88, 108, 110],
#         [ 85, 112, 113],
#         [ 87, 114, 115]],
#
#        [[ 91,  80,  55],
#         [ 84,  73,  48],
#         [ 71,  60,  35],
#         ...,
#         [ 88, 108, 110],
#         [ 85, 112, 113],
#         [ 87, 114, 115]],
#
#        ...,
#
#        [[ 67,  75,  74],
#         [ 20,  28,  27],
#         [  0,   6,   5],
#         ...,
#         [ 28,  61,  85],
#         [ 28,  61,  85],
#         [ 28,  61,  85]],
#
#        [[ 84,  92,  91],
#         [ 52,  60,  59],
#         [ 32,  40,  39],
#         ...,
#         [ 40,  69,  83],
#         [ 40,  69,  83],
#         [ 40,  69,  83]],
#
#        [[111, 119, 118],
#         [ 48,  56,  55],
#         [ 20,  28,  27],
# ...
