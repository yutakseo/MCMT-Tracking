# %%
from MCMT_engine.video_SCST import videoSCST

# %%
class Args:
    track_thresh = 0.3
    match_thresh = 0.9
    track_buffer = 180
    mot20 = False
    cpu_workers = 20   # 듀얼 CPU 적극 활용
    chunk_sec   = 10.0 # 15~30초 권장
    batch_size = 20
args = Args()


CLASSES= ["People"]

# %%
# 1) 도면 + (선택) H 로드
plan_path = "/workspace/assets/250904_homograph_coordinate-plane2.jpg"
plan_pts  = [
                (1170,  214),    #point1
                (1170,  559),   #point2
                (1170,  904),   #point3
                (2212,  214),    #point4
                (2212,  559),   #point5
                (2212,  904),   #point6
                (3255,  214),     #point7
                (3255,  559),    #point8
                (3255,  904),    #point9
                ]

# %%
scst = videoSCST(
    args=args,
    plan_img_path=plan_path,
    plan_pts=plan_pts,
    det_class_names=CLASSES,
    det_models=["ultra_people", "worker"]
)
# Out:
# [DEBUG] VehicleDetector loaded with Ultralytics YOLO on cuda:0
# Loads checkpoint by local backend from path: /workspace/PretrainedModel_by_JeonYT/worker/epoch_100.pth
# [DEBUG] WorkerDetector loaded on device=cuda:0
# Parameter device: cuda:0

# %% [markdown]
# ### Cam#1

# %%
results1 = scst.track_and_save(
    video_path="/workspace/datasets/homography_experiment2/1100-1110/2025-09-04 10_59_59 이동형 #1_part_000.mp4",
    cctv_pts=[(1033,475),
            (948,474),
            (863,473),
            (1019,527),
            (890,524),
            (769,519),
            (973,667),
            (741,652),
            (548,620)],  # 켈리브레이션
    camera_save_path="/workspace/results/tracking_result1.mp4",  # 카메라 영상 저장
    plan_save_path="/workspace/results/plan_result1.mp4"       # 도면 영상 저장
)
# Out:
# [INFO] Camera calibration completed successfully
# /opt/conda/envs/mmyolo/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [INFO] Camera view saved: /workspace/results/tracking_result1.mp4, frames: 18012
# [INFO] Plan projection saved: /workspace/results/plan_result1.mp4

# %% [markdown]
# ### Cam#2

# %%
results2 = scst.track_and_save(
    video_path="/workspace/datasets/homography_experiment2/1100-1110/2025-09-04 10_59_58 이동형 #2_part_000.mp4",
    cctv_pts=[(518,466),
            (430,471),
            (341,474),
            (613,510),
            (485,519),
            (354,527),
            (829,608), 
            (634,645),
            (397,668)],  # 켈리브레이션
    camera_save_path="/workspace/results/tracking_result2.mp4",  # 카메라 영상 저장
    plan_save_path="/workspace/results/plan_result2.mp4"       # 도면 영상 저장
)
# Out:
# [INFO] Camera calibration completed successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c5dcb499cbdc> in <cell line: 1>()
# ----> 1 results2 = scst.track_and_save(
#       2     video_path="/workspace/datasets/homography_experiment2/1100-1110/2025-09-04 10_59_58 이동형 #2_part_000.mp4",
#       3     cctv_pts=[(518,466),
#       4             (430,471),
#       5             (341,474),
#
# /workspace/MCMT_engine/video_SCST.py in track_and_save(self, video_path, cctv_pts, camera_save_path, plan_save_path, plan_mode, cam_trail_len, ransac_thresh)
#     190
#     191         try:
# --> 192             for _, frame in stream:
#     193                 batch_frames.append(frame)
#     194                 if batch_raw is not None:
#
# /workspace/MCMT_engine/video_SCST.py in _ordered_stream(self, frame_stream)
#      98         buffer = {}
#      99         expected = None
# --> 100         for idx, frame in frame_stream:
#     101             if frame is None or frame.size == 0:
#     102                 continue
#
# /workspace/__Tracking/utils/video_decoder.py in iter_frames_parallel(video_path, cpu_workers, chunk_sec)
#      59
#      60     n_workers = min(max(1, int(cpu_workers)), len(chunks))
# ---> 61     with mp.get_context("spawn").Pool(processes=n_workers) as pool:
#      62         for out in pool.imap(_cpu_decode_worker, [(video_path, c) for c in chunks]):
#      63             out.sort(key=lambda x: x[0])
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117         '''Returns a process pool object'''
#     118         from .pool import Pool
# --> 119         return Pool(processes, initializer, initargs, maxtasksperchild,
#     120                     context=self.get_context())
#     121
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     210         self._processes = processes
#     211         try:
# --> 212             self._repopulate_pool()
#     213         except Exception:
#     214             for p in self._pool:
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/pool.py in _repopulate_pool(self)
#     301
#     302     def _repopulate_pool(self):
# --> 303         return self._repopulate_pool_static(self._ctx, self.Process,
#     304                                             self._processes,
#     305                                             self._pool, self._inqueue,
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/pool.py in _repopulate_pool_static(ctx, Process, processes, pool, inqueue, outqueue, initializer, initargs, maxtasksperchild, wrap_exception)
#     324             w.name = w.name.replace('Process', 'PoolWorker')
#     325             w.daemon = True
# --> 326             w.start()
#     327             pool.append(w)
#     328             util.debug('added worker')
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/process.py in start(self)
#     119                'daemonic processes are not allowed to have children'
#     120         _cleanup()
# --> 121         self._popen = self._Popen(self)
#     122         self._sentinel = self._popen.sentinel
#     123         # Avoid a refcycle if the target function holds an indirect
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/context.py in _Popen(process_obj)
#     282         def _Popen(process_obj):
#     283             from .popen_spawn_posix import Popen
# --> 284             return Popen(process_obj)
#     285
#     286     class ForkServerProcess(process.BaseProcess):
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/popen_spawn_posix.py in __init__(self, process_obj)
#      30     def __init__(self, process_obj):
#      31         self._fds = []
# ---> 32         super().__init__(process_obj)
#      33
#      34     def duplicate_for_child(self, fd):
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      17         self.returncode = None
#      18         self.finalizer = None
# ---> 19         self._launch(process_obj)
#      20
#      21     def duplicate_for_child(self, fd):
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/popen_spawn_posix.py in _launch(self, process_obj)
#      56                                          pipe_handle=child_r)
#      57             self._fds.extend([child_r, child_w])
# ---> 58             self.pid = util.spawnv_passfds(spawn.get_executable(),
#      59                                            cmd, self._fds)
#      60             self.sentinel = parent_r
#
# /opt/conda/envs/mmyolo/lib/python3.8/multiprocessing/util.py in spawnv_passfds(path, args, passfds)
#     450     errpipe_read, errpipe_write = os.pipe()
#     451     try:
# --> 452         return _posixsubprocess.fork_exec(
#     453             args, [os.fsencode(path)], True, passfds, None, None,
#     454             -1, -1, -1, -1, -1, -1, errpipe_read, errpipe_write,
#
# KeyboardInterrupt:

# %% [markdown]
#  ### Cam#3

# %%
results3 = scst.track_and_save(
    video_path="/workspace/datasets/homography_experiment2/1100-1110/2025-09-04 10_59_58 이동형 #3_part_000.mp4",
    cctv_pts=[(357,602),
            (566,648),
            (832,683),
            (620,498),
            (754,509),
            (893,513),
            (726,453),
            (819,456),
            (911,459)],  # 켈리브레이션
    camera_save_path="/workspace/results/tracking_result3.mp4",  # 카메라 영상 저장
    plan_save_path="/workspace/results/plan_result3.mp4"         # 도면 영상 저장
)
